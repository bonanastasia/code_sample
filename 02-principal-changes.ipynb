# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Calculate changes months

# %%
# Read the CSV file
principal_rosters = pd.read_csv("../data-processed/updates/feb_principal_rosters.csv")

# %% [markdown]
# ## Backfill NAs
# First we're going to take our backfilled data from R and we'll deal with sandwiched NA values. If an NA values (or multiple NA values are between two matching values, we'll fill in those gaps in the rosters data)

# %%
def replace_na_with_nearest_match(data):
    # Convert data to pandas DataFrame
    df = pd.DataFrame(data)
    
    # Iterate over each row
    for idx, row in df.iterrows():
        # Iterate over each column
        for col_idx, col in enumerate(row):
            # If the value is NA
            if pd.isna(col):
                # Find the nearest non-NA value to the left
                left_idx = col_idx - 1
                while left_idx >= 0 and pd.isna(row[left_idx]):
                    left_idx -= 1
                left_value = row[left_idx] if left_idx >= 0 else None
                
                # Find the nearest non-NA value to the right
                right_idx = col_idx + 1
                while right_idx < len(row) and pd.isna(row[right_idx]):
                    right_idx += 1
                right_value = row[right_idx] if right_idx < len(row) else None
                
                # If both left and right values match, replace NA with the match
                if left_value == right_value:
                    df.at[idx, df.columns[col_idx]] = left_value
                    
    return df

# %%
principal_rosters_na_backfilled = replace_na_with_nearest_match(principal_rosters)

principal_rosters_na_backfilled.head(10)
# Out:
#    campus   campus_name      nes_flag division     principal_june  \
# 0       1     austin hs  NES Fall '24  central      orlando reyna
# 1       2   bellaire hs       Not NES     west     michael niggli
# 2       3  northside hs  NES Fall '24  central   cecilia gonzales
# 3       4       furr hs   NES-Aligned  central       tammie moran
# 4       6      jones hs       Not NES    south       janet orozco
# 5       7   kashmere hs           NES    north  brandon dickerson
# 6       8      lamar hs       Not NES  central        rita graves
# 7       9     wisdom hs   NES-Aligned     west   kenneth brantley
# 8      10    madison hs   NES-Aligned    south      yolanda bruce
# 9      11      milby hs       Not NES    south          ruth pena
#
#       principal_july      principal_aug     principal_sept      principal_oct  \
# 0      orlando reyna      orlando reyna      orlando reyna      orlando reyna
# 1     michael niggli     michael niggli     michael niggli     michael niggli
# 2   cecilia gonzales      victor garcia      victor garcia      victor garcia
# 3       tammie moran       tammie moran       tammie moran       tammie moran
# 4       janet orozco       janet orozco       janet orozco       janet orozco
# 5  brandon dickerson  brandon dickerson  brandon dickerson  brandon dickerson
# 6        rita graves        rita graves        rita graves        rita graves
# 7   kenneth brantley   kenneth brantley   kenneth brantley                NaN
# 8      yolanda bruce        tanisha lee        tanisha lee        tanisha lee
# 9          ruth pena          ruth pena          ruth pena          ruth pena
#
#        principal_nov      principal_dec      principal_jan      principal_feb
# 0      orlando reyna      orlando reyna      orlando reyna      orlando reyna
# 1     michael niggli     michael niggli     michael niggli     michael niggli
# 2      victor garcia      victor garcia      victor garcia      victor garcia
# 3       tammie moran       tammie moran       tammie moran       tammie moran
# 4       janet orozco       janet orozco       janet orozco       janet orozco
# 5  brandon dickerson  brandon dickerson  brandon dickerson  brandon dickerson
# 6        rita graves        rita graves        rita graves        rita graves
# 7      reginald bush      reginald bush      reginald bush      reginald bush
# 8        tanisha lee    edgar contreras    edgar contreras    edgar contreras
# 9          ruth pena          ruth pena          ruth pena          ruth pena

# %%
principal_rosters_na_backfilled[principal_rosters_na_backfilled['campus_name'] == 'burrus es']
# Out:
#     campus campus_name     nes_flag division   principal_june  \
# 86     125   burrus es  NES-Aligned    north  nicole williams
#
#      principal_july    principal_aug   principal_sept    principal_oct  \
# 86  nicole williams  nicole williams  nicole williams  nicole williams
#
#       principal_nov    principal_dec    principal_jan    principal_feb
# 86  nicole williams  nicole williams  nicole williams  nicole williams

# %% [markdown]
# ## Calculate changes
# Now that we've backfilled our data, we'll use Python to check for months with changes and save the months where they occurred for us.

# %%
# Read the CSV file
df = principal_rosters_na_backfilled

# Initialize an empty list to store changes columns for each row
incoming_months_list = []
outgoing_months_list = []
incoming_principals_list = []
principal_cols = [col for col in df if col.startswith('principal_')]

#changes = pd.DataFrame()
changes_rows = [] # initialize empty list to store changes rows for our changes df

# Iterate over each row in the dataframe
for index, row in df.iterrows():
    prev_name = None
    incoming_months = []  # Initialize changes columns for the current row
    outgoing_month_columns = []  # Initialize outgoing month columns for the current row
    principals_columns = []  # Initialize principal changes columns for the current row
    
    # Iterate over each name column
    for col in principal_cols:
        current_name = row[col]
        
        # Skip NA values
        if pd.isna(current_name) and col != 'principal_feb':
            continue
        
        # Check if there is a change from the previous name
        if (prev_name is not None and current_name != prev_name):
            incoming_months.append(col.replace('principal_', ''))
            ## find closest non na value to the left
            left_idx = principal_cols.index(col) - 1
            while left_idx >= 0 and pd.isna(row[principal_cols[left_idx]]):
                left_idx -= 1
            left_value = row[principal_cols[left_idx]] if left_idx >= 0 else None
            # append the outgoing month column to the outgoing_month_columns list
            outgoing_month_columns.append(principal_cols[left_idx].replace('principal_', ''))

            
            # Append the incoming_months list to the incoming_months_list
            change_row = {
            'campus': row['campus'], 
            'campus_name': row['campus_name'],
            # get outgoing principal and month
            'outgoing_principal': left_value,
            'outgoing_month': principal_cols[left_idx].replace('principal_', ''),
             # get incoming principal and month
            'incoming_principal': current_name,
            'incoming_month': col.replace('principal_', ''),
            }
            changes_rows.append(change_row)
        
        prev_name = current_name

    
    # Append the incoming_months list to the incoming_months_list
    incoming_months_list.append(incoming_months)
    outgoing_months_list.append(outgoing_month_columns)

    changes_only = pd.DataFrame(changes_rows)

## THIS IS WHERE WE WERE
changes_only.head(100)
# Out:
#     campus                campus_name  outgoing_principal outgoing_month  \
# 0        3               northside hs    cecilia gonzales           july
# 1        9                  wisdom hs    kenneth brantley           sept
# 2       10                 madison hs       yolanda bruce           july
# 3       10                 madison hs         tanisha lee            nov
# 4       19                worthing hs        everett hare           july
# ..     ...                        ...                 ...            ...
# 68     382         reagan ed ctr pk-8     lauren mailhiot           june
# 69     456  high school ahead acad ms        john flowers            aug
# 70     479               shadydale es        teri hampton           july
# 71     485  middle college hs - fraga  federico hernandez            oct
# 72     486                south ec hs     steven gourrier            aug
#
#      incoming_principal incoming_month
# 0         victor garcia            aug
# 1         reginald bush            nov
# 2           tanisha lee            aug
# 3       edgar contreras            dec
# 4   alexandria gregoire           sept
# ..                  ...            ...
# 68        gloria robayo            aug
# 69      megan lyndersay           sept
# 70        pandora agnew            aug
# 71                  NaN            feb
# 72        angelica vega            nov
#
# [73 rows x 6 columns]

# %% [markdown]
# Spread changes to new columns

# %%
# Add the changes_columns_list as a new column to the dataframe
df['incoming_months_columns'] = incoming_months_list

# Unnest the values in the `changes_columns` and spread them to new columns
max_changes = df['incoming_months_columns'].apply(len).max()
print(max_changes)
for i in range(1, max_changes + 1):
    df[f'incoming_month_{i}'] = df['incoming_months_columns'].apply(lambda x: x[i-1] if len(x) >= i else None)

# Drop the original `changes_columns` column
#df.drop(columns=['changes_columns'], inplace=True)
    
df['outgoing_months_columns'] = outgoing_months_list
for i in range(1, max_changes + 1):
    df[f'outgoing_month_{i}'] = df['outgoing_months_columns'].apply(lambda x: x[i-1] if len(x) >= i else None)
    
df
# Out:
# 2
#      campus                  campus_name      nes_flag division  \
# 0         1                    austin hs  NES Fall '24  central
# 1         2                  bellaire hs       Not NES     west
# 2         3                 northside hs  NES Fall '24  central
# 3         4                      furr hs   NES-Aligned  central
# 4         6                     jones hs       Not NES    south
# ..      ...                          ...           ...      ...
# 269     480                  marshall es           NES    north
# 270     483                   white m es       Not NES     west
# 271     484  middle college hs - gulfton           NaN     west
# 272     485    middle college hs - fraga           NaN  central
# 273     486                  south ec hs       Not NES    south
#
#          principal_june      principal_july       principal_aug  \
# 0         orlando reyna       orlando reyna       orlando reyna
# 1        michael niggli      michael niggli      michael niggli
# 2      cecilia gonzales    cecilia gonzales       victor garcia
# 3          tammie moran        tammie moran        tammie moran
# 4          janet orozco        janet orozco        janet orozco
# ..                  ...                 ...                 ...
# 269        lauren price        lauren price        lauren price
# 270      lisa hernandez      lisa hernandez      lisa hernandez
# 271        holly gibson        holly gibson        holly gibson
# 272  federico hernandez  federico hernandez  federico hernandez
# 273     steven gourrier     steven gourrier     steven gourrier
#
#          principal_sept       principal_oct   principal_nov   principal_dec  \
# 0         orlando reyna       orlando reyna   orlando reyna   orlando reyna
# 1        michael niggli      michael niggli  michael niggli  michael niggli
# 2         victor garcia       victor garcia   victor garcia   victor garcia
# 3          tammie moran        tammie moran    tammie moran    tammie moran
# 4          janet orozco        janet orozco    janet orozco    janet orozco
# ..                  ...                 ...             ...             ...
# 269        lauren price        lauren price    lauren price    lauren price
# 270      lisa hernandez      lisa hernandez  lisa hernandez  lisa hernandez
# 271        holly gibson        holly gibson    holly gibson    holly gibson
# 272  federico hernandez  federico hernandez             NaN             NaN
# 273                 NaN                 NaN   angelica vega   angelica vega
#
#       principal_jan   principal_feb incoming_months_columns incoming_month_1  \
# 0     orlando reyna   orlando reyna                      []             None
# 1    michael niggli  michael niggli                      []             None
# 2     victor garcia   victor garcia                   [aug]              aug
# 3      tammie moran    tammie moran                      []             None
# 4      janet orozco    janet orozco                      []             None
# ..              ...             ...                     ...              ...
# 269    lauren price    lauren price                      []             None
# 270  lisa hernandez  lisa hernandez                      []             None
# 271    holly gibson    holly gibson                      []             None
# 272             NaN             NaN                   [feb]              feb
# 273   angelica vega   angelica vega                   [nov]              nov
#
#     incoming_month_2 outgoing_months_columns outgoing_month_1 outgoing_month_2
# 0               None                      []             None             None
# 1               None                      []             None             None
# 2               None                  [july]             july             None
# 3               None                      []             None             None
# 4               None                      []             None             None
# ..               ...                     ...              ...              ...
# 269             None                      []             None             None
# 270             None                      []             None             None
# 271             None                      []             None             None
# 272             None                   [oct]              oct             None
# 273             None                   [aug]              aug             None
#
# [274 rows x 19 columns]

# %% [markdown]
# ### Export changes df

# %%
# get the last index of the principal columns
last_index = principal_cols[len(principal_cols) - 1].replace('principal_', '')

last_index
# Out:
# 'feb'

# %%
df[df['campus_name'] == 'burrus es']
# Out:
#     campus campus_name     nes_flag division   principal_june  \
# 86     125   burrus es  NES-Aligned    north  nicole williams
#
#      principal_july    principal_aug   principal_sept    principal_oct  \
# 86  nicole williams  nicole williams  nicole williams  nicole williams
#
#       principal_nov    principal_dec    principal_jan    principal_feb  \
# 86  nicole williams  nicole williams  nicole williams  nicole williams
#
#    incoming_months_columns incoming_month_1 incoming_month_2  \
# 86                      []             None             None
#
#    outgoing_months_columns outgoing_month_1 outgoing_month_2
# 86                      []             None             None

# %%
changes_only.to_csv("../data-processed/processed-python/changes_only--" + last_index + ".csv", index=False)
df.to_csv("../data-processed/processed-python/full_principals_with_changes--" + last_index + ".csv", index=False)

# %%
df.count()
# Out:
# campus                     274
# campus_name                274
# nes_flag                   254
# division                   274
# principal_june             259
# principal_july             256
# principal_aug              253
# principal_sept             257
# principal_oct              256
# principal_nov              259
# principal_dec              260
# principal_jan              257
# principal_feb              257
# incoming_months_columns    274
# incoming_month_1            66
# incoming_month_2             7
# outgoing_months_columns    274
# outgoing_month_1            66
# outgoing_month_2             7
# dtype: int64

# %%
changes_only.count()
# Out:
# campus                73
# campus_name           73
# outgoing_principal    73
# outgoing_month        73
# incoming_principal    68
# incoming_month        73
# dtype: int64
